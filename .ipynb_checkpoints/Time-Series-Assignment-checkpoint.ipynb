# %%
# Downloading stock information
import datetime
import pandas_datareader.data as web
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
start = datetime.datetime(2012,7,21)
end = datetime.datetime(2017,6,30)
aapl = web.DataReader('AAPL', 'google', start, end)
bbry = web.DataReader('BBRY', 'google', start, end)
lulu = web.DataReader('LULU', 'google', start, end)
amzn = web.DataReader('AMZN', 'google', start, end)

# %%
print(aapl.columns)
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2012-07-23   84.91   86.56   83.96   86.26  121993795
# 2012-07-24   86.77   87.10   85.50   85.85  141283044
# 2012-07-25   82.07   82.97   81.43   82.14  219314368
# 2012-07-26   82.82   82.91   81.48   82.13  101702580
# 2012-07-27   82.14   83.69   81.66   83.59  101013241
# 2012-07-30   84.42   85.63   83.97   85.00   94784970
# 2012-07-31   86.18   87.39   86.10   87.25  115581676
# 2012-08-01   87.99   88.06   86.14   86.69   96124742
# 2012-08-02   86.12   87.24   85.75   86.83   83062203
# 2012-08-03   87.66   88.28   87.37   87.96   86228604
# 2012-08-06   88.18   89.27   87.89   88.94   75580008
# 2012-08-07   88.97   89.29   88.29   88.70   72627492
# 2012-08-08   88.48   89.13   88.16   88.55   61176080
# 2012-08-09   88.26   88.82   88.26   88.68   55452586
# 2012-08-10   88.39   88.82   88.39   88.81   48765045
# 2012-08-13   89.06   90.00   89.04   90.00   69707463
# ...
